# %%
# Import and visualise the non quantized NN first

# %%
from finn.util.visualization import showInNetron

showInNetron('./finn_lenet_non_quantized.onnx')
# Out:
# Serving './finn_lenet_non_quantized.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ![finn_lenet_non_quantized.onnx.png](attachment:finn_lenet_non_quantized.onnx.png)

# %%
# Import and visualise the quantized NN now (MultiThreshold layers enforce quantization)

# %%
showInNetron('./finn_lenet.onnx')
# Out:
# Stopping http://0.0.0.0:8081
# Serving './finn_lenet.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://localhost:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ![finn_lenet.onnx.png](attachment:finn_lenet.onnx.png)
